# %% [markdown]
# # Download L1B, in safe format, then transform to ZARR

# %% [markdown]
# ## Download the safe format file
# ### Import dependencies for downloading Safe format.

# %%
import os
import boto3
from dotenv import load_dotenv

# %% [markdown]
# ### Setup and Environment Configuration
#
# First, we'll import the required libraries and set up our environment. Make sure your Copernicus credentials are stored in your environment variables or a `.env` file.

# %%
import boto3
import os

# Get credentials from environment variables
load_dotenv()
ACCESS_KEY_ID = os.environ.get("ACCESS_KEY_ID")
SECRET_ACCESS_KEY = os.environ.get("SECRET_ACCESS_KEY")


session = boto3.session.Session()
s3 = boto3.resource(
    's3',
    endpoint_url='https://eodata.dataspace.copernicus.eu',
    aws_access_key_id=ACCESS_KEY_ID,
    aws_secret_access_key=SECRET_ACCESS_KEY,
    region_name='default'
)  # generated secrets

def download(bucket, product: str, target: str = "") -> None:
    """
    Downloads every file in bucket with provided product as prefix

    Raises FileNotFoundError if the product was not found

    Args:
        bucket: boto3 Resource bucket object
        product: Path to product
        target: Local catalog for downloaded files. Should end with an `/`. Default current directory.
    """
    files = bucket.objects.filter(Prefix=product)
    if not list(files):
        raise FileNotFoundError(f"Could not find any files for {product}")
    for file in files:
        os.makedirs(os.path.dirname(file.key), exist_ok=True)
        if not os.path.isdir(file.key):
            bucket.download_file(file.key, f"{target}{file.key}")

# path to the product to download
download(s3.Bucket("eodata"), #"Sentinel-1/SAR/SLC/2019/10/13/S1B_IW_SLC__1SDV_20191013T155948_20191013T160015_018459_022C6B_13A2.SAFE/"
        "Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T145646_S20250724T112818_D07_N05.11.tar")

# %% [markdown]
# ### Connecting to Copernicus Data Space Ecosystem
#
# Now let's establish connections to both the S3 storage and STAC catalog services using our credentials.

# %%
# !ls Sentinel-2
# Out:
# MSI

# %%
import boto3
import os
from dotenv import load_dotenv

# Load credentials from .env
load_dotenv()
ACCESS_KEY_ID = os.environ.get("ACCESS_KEY_ID")
SECRET_ACCESS_KEY = os.environ.get("SECRET_ACCESS_KEY")

# Initialize S3 resource for CDSE
session = boto3.session.Session()
s3 = session.resource(
    's3',
    endpoint_url='https://eodata.dataspace.copernicus.eu',
    aws_access_key_id=ACCESS_KEY_ID,
    aws_secret_access_key=SECRET_ACCESS_KEY,
    region_name='default'
)
def download_all_under_prefix(bucket, prefix: str, target: str = "") -> None:
    """
    Recursively downloads all files under a given prefix (folder-like path)

    Args:
        bucket: boto3 Bucket resource
        prefix: S3 prefix (folder path) to mirror
        target: Local base folder to store downloaded files
    """
    files = bucket.objects.filter(Prefix=prefix)
    count = 0
    for file in files:
        # Full local path
        local_path = os.path.join(target, file.key)
        # Ensure destination directory exists
        os.makedirs(os.path.dirname(local_path), exist_ok=True)
        # Skip directories (S3 can list empty 'folders')
        if not file.key.endswith("/"):
            print(f"⬇️  Downloading {file.key}")
            bucket.download_file(file.key, local_path)
            count += 1
    if count == 0:
        raise FileNotFoundError(f"❌ No files found under {prefix}")
    print(f"✅ Downloaded {count} files under {prefix}")

# Call the function on your desired folder
download_all_under_prefix(
    bucket=s3.Bucket("eodata"),
    prefix="Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/",
    target="S2_L1B_20250724"  # Local folder
)
# Out:
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000002_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000005_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000006_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000009_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000012_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000013_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000016_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000020_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000023_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000024_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011624_S20250724T000027_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000322_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000325_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000326_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000329_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000330_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000333_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000336_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000337_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000340_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000344_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000347_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000348_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000351_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000354_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000355_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000358_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000402_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000405_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000406_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000409_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000409_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000409_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000409_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000557_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000558_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000601_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000604_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000605_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D02_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D12_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D04_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D10_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D08_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D06_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D07_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D05_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D09_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D03_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D11_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000608_D01_N05.11.tar
# ⬇️  Downloading Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/S2A_OPER_MSI_L1B_GR_2APS_20250724T011636_S20250724T000611_D02_N05.11.tar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 45
#      42     print(f"✅ Downloaded {count} files under {prefix}")
#      44 # Call the function on your desired folder
# ---> 45 download_all_under_prefix(
#      46     bucket=s3.Bucket("eodata"),
#      47     prefix="Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/",
#      48     target="S2_L1B_20250724"  # Local folder
#      49 )
#
# Cell In[2], line 38, in download_all_under_prefix(bucket, prefix, target)
#      36     if not file.key.endswith("/"):
#      37         print(f"⬇️  Downloading {file.key}")
# ---> 38         bucket.download_file(file.key, local_path)
#      39         count += 1
#      40 if count == 0:
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/boto3/s3/inject.py:279, in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     245 def bucket_download_file(
#     246     self, Key, Filename, ExtraArgs=None, Callback=None, Config=None
#     247 ):
#     248     """Download an S3 object to a file.
#     249
#     250     Usage::
#    (...)
#     277         transfer.
#     278     """
# --> 279     return self.meta.client.download_file(
#     280         Bucket=self.name,
#     281         Key=Key,
#     282         Filename=Filename,
#     283         ExtraArgs=ExtraArgs,
#     284         Callback=Callback,
#     285         Config=Config,
#     286     )
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/boto3/s3/inject.py:192, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     157 """Download an S3 object to a file.
#     158
#     159 Usage::
#    (...)
#     189     transfer.
#     190 """
#     191 with S3Transfer(self, Config) as transfer:
# --> 192     return transfer.download_file(
#     193         bucket=Bucket,
#     194         key=Key,
#     195         filename=Filename,
#     196         extra_args=ExtraArgs,
#     197         callback=Callback,
#     198     )
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/boto3/s3/transfer.py:406, in S3Transfer.download_file(self, bucket, key, filename, extra_args, callback)
#     402 future = self._manager.download(
#     403     bucket, key, filename, extra_args, subscribers
#     404 )
#     405 try:
# --> 406     future.result()
#     407 # This is for backwards compatibility where when retries are
#     408 # exceeded we need to throw the same error from boto3 instead of
#     409 # s3transfer's built in RetriesExceededError as current users are
#     410 # catching the boto3 one instead of the s3transfer exception to do
#     411 # their own retries.
#     412 except S3TransferRetriesExceededError as e:
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/s3transfer/futures.py:106, in TransferFuture.result(self)
#     104 except KeyboardInterrupt as e:
#     105     self.cancel()
# --> 106     raise e
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/s3transfer/futures.py:259, in TransferCoordinator.result(self)
#     249 """Waits until TransferFuture is done and returns the result
#     250
#     251 If the TransferFuture succeeded, it will return the result. If the
#     252 TransferFuture failed, it will raise the exception associated to the
#     253 failure.
#     254 """
#     255 # Doing a wait() with no timeout cannot be interrupted in python2 but
#     256 # can be interrupted in python3 so we just wait with the largest
#     257 # possible value integer value, which is on the scale of billions of
#     258 # years...
# --> 259 self._done_event.wait(MAXINT)
#     261 # Once done waiting, raise an exception if present or return the
#     262 # final result.
#     263 if self._exception:
#
# File /srv/conda/envs/notebook/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /srv/conda/envs/notebook/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import boto3
import os
from dotenv import load_dotenv

# Load credentials
load_dotenv()
ACCESS_KEY_ID = os.environ["ACCESS_KEY_ID"]
SECRET_ACCESS_KEY = os.environ["SECRET_ACCESS_KEY"]

# Initialize S3 session
session = boto3.session.Session()
s3 = session.resource(
    's3',
    endpoint_url='https://eodata.dataspace.copernicus.eu',
    aws_access_key_id=ACCESS_KEY_ID,
    aws_secret_access_key=SECRET_ACCESS_KEY,
    region_name='default'
)

def get_total_size(bucket, prefix):
    """
    Returns the total size (in bytes) and file count under a given prefix.
    """
    total_bytes = 0
    file_count = 0

    for obj in bucket.objects.filter(Prefix=prefix):
        if not obj.key.endswith("/"):  # skip folders
            total_bytes += obj.size
            file_count += 1

    return total_bytes, file_count

# Run it
prefix = "Sentinel-2/MSI/MSI_L1B_GR/2025/07/24/"
bucket = s3.Bucket("eodata")
total_bytes, file_count = get_total_size(bucket, prefix)

# Print nicely
print(f"📦 Total files: {file_count}")
print(f"🧮 Total size: {total_bytes / (1024**3):.2f} GB")
# Out:
# 📦 Total files: 94936
# 🧮 Total size: 2007.51 GB

# %%
# Run it
prefix = "Sentinel-2/MSI/MSI_L1B_GR/2025/07/23/"
bucket = s3.Bucket("eodata")
total_bytes, file_count = get_total_size(bucket, prefix)

# Print nicely
print(f"📦 Total files: {file_count}")
print(f"🧮 Total size: {total_bytes / (1024**3):.2f} GB")
