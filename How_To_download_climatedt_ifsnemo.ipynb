# %% [markdown]
# # Access Climate DT data with polytope
#
# Connect to https://code.insula.destine.eu/

# %%
import polytope
import xarray as xr

# %%
#%run ../desp-authentication.py
rcfile = "~/.polytopeapirc"

# %% [markdown]
# ## Request data
# - Check [ECMWF Climate DT Overview](https://confluence.ecmwf.int/display/DDCZ/DestinE%2BClimateDT%2BParameters?) to get information on possible values for each field, e.g. parameters from the ECMWF Parameter Database.
#
# Or check Climate_dt_dictionary

# %%
from destinelab import climate_dt_dictionary

# パラメータ辞書から param と名前、単位などを確認
for entry in climate_dt_dictionary.climateDT_params:
#    print(entry)
    if entry["param"] == "168":
        print(entry)
# Out:
# {'param': '168', 'paramName': '2 metre dewpoint temperature', 'shortName': '2d', 'unit': 'K', 'encoding': 'instantaneous', 'isNemo': 'IFS-NEMO', 'isIcon': 'ICON', 'isFESOM': 'IFS-FESOM', 'stream': 'clte', 'type': 'fc', 'time': 'Hourly', 'levtype': 'sfc', 'levelist': ''}

# %%
kwargs = {"address": "polytope.lumi.apps.dte.destination-earth.eu"}
client = polytope.api.Client(**kwargs)

# %%
client.list_collections()
# Out:
# 2025-09-05 10:45:02 - INFO - Key read from /home/jovyan/.polytopeapirc
# 2025-09-05 10:45:02 - INFO - Fetching collections...
# 2025-09-05 10:45:02 - INFO - Polytope user key found in session cache for user jovyan
# 2025-09-05 10:45:03 - INFO - The following collections are available:
#   - destination-earth
# ['destination-earth']

# %%
request = {
    'activity': 'ScenarioMIP',
    'class': 'd1',
    'dataset': 'climate-dt',
    'date': '20200102',
    'experiment': 'SSP3-7.0',
    'expver': '0001',
    'generation': '1',
    'levtype': 'sfc',
    'model': 'IFS-NEMO',
    'param': '134/165/166/167',
    'realization': '1',
    'resolution': 'highres',#'standard',#'highres',
    'stream': 'clte',
    'time': '0100', # '0100/0200/0300/0400/0500/0600'
    'type': 'fc'
}

# %%
# Retrieve data
client.retrieve("destination-earth", request, "output_ifsnemo_highres.grib")
# Out:
# 2025-09-05 11:06:40 - INFO - Polytope user key found in session cache for user jovyan
# 2025-09-05 11:06:40 - INFO - Sending request...
# {'request': 'activity: ScenarioMIP\n'
#             'class: d1\n'
#             'dataset: climate-dt\n'
#             "date: '20200102'\n"
#             'experiment: SSP3-7.0\n'
#             "expver: '0001'\n"
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-NEMO\n'
#             'param: 134/165/166/167\n'
#             "realization: '1'\n"
#             'resolution: highres\n'
#             'stream: clte\n'
#             "time: '0100'\n"
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2025-09-05 11:06:40 - INFO - Polytope user key found in session cache for user jovyan
# 2025-09-05 11:06:42 - INFO - Request accepted. Please poll ./bc38c447-acc3-47af-a4d6-e3259d7343c7 for status
# 2025-09-05 11:06:42 - INFO - Polytope user key found in session cache for user jovyan
# 2025-09-05 11:06:42 - INFO - Checking request status (./bc38c447-acc3-47af-a4d6-e3259d7343c7)...
# 2025-09-05 11:06:42 - INFO - The current status of the request is 'queued'
# 2025-09-05 11:06:43 - INFO - The current status of the request is 'processing'
# 2025-09-05 11:06:46 - INFO - The current status of the request is 'processed'
# 2025-09-05 11:06:46 - INFO - Starting data download (application/x-grib)...
# 2025-09-05 11:06:46 - INFO - Saving data into output_ifsnemo_highres.grib...
# 2025-09-05 11:06:53 - INFO - Data downloaded successfully
# 2025-09-05 11:06:53 - INFO - Download rate 15.4MiB/s
# 2025-09-05 11:06:53 - INFO - Data saved successfully into output_ifsnemo_highres.grib
# ['output_ifsnemo_highres.grib']

# %%
dset = xr.open_dataset("output_ifsnemo_highres.grib", engine="cfgrib")
# Out:
# Ignoring index file 'output_ifsnemo_highres.grib.9093e.idx' older than GRIB file
# skipping variable: paramId==167 shortName='t2m'
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/cfgrib/dataset.py", line 701, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/opt/conda/lib/python3.11/site-packages/cfgrib/dataset.py", line 629, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveGround' value=Variable(dimensions=(), data=10.0) new_value=Variable(dimensions=(), data=2.0)

# %%
dset
# Out:
# <xarray.Dataset> Size: 352MB
# Dimensions:            (values: 12582912)
# Coordinates:
#     time               datetime64[ns] 8B ...
#     step               timedelta64[ns] 8B ...
#     surface            float64 8B ...
#     latitude           (values) float64 101MB ...
#     longitude          (values) float64 101MB ...
#     valid_time         datetime64[ns] 8B ...
#     heightAboveGround  float64 8B ...
# Dimensions without coordinates: values
# Data variables:
#     sp                 (values) float32 50MB ...
#     u10                (values) float32 50MB ...
#     v10                (values) float32 50MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          1003
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-09-05T11:06 GRIB to CDM+CF via cfgrib-0.9.1...
